# %%
import pandas as pd
from ydata_profiling import ProfileReport
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
from sklearn.model_selection import KFold
import lightgbm as lgb
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
test_df = pd.read_csv("date/test.csv")
train_df = pd.read_csv("date/train.csv")
weather = pd.read_csv("date/weather.csv")
sample = pd.read_csv("date/sample_submission.csv")

# %%
train_df = train_df.drop(columns=['amount'])

# %%
def Data_cre(df):
    # --- area を分解して複数行に展開 ---
    df["area_list"] = df["area"].str.split("_")

    # explodeで行を増やす
    df = df.explode("area_list")
    df = df.drop(columns=["area"])
    df = df.rename(columns={"area_list": "area"})

    # --- 日付フォーマット揃え ---
    df["date"] = df["date"].astype(str)
    df["date"] = pd.to_datetime(df["date"])

    # --- weather と結合 ---
    df = pd.merge(df, weather, on=["date", "area"], how="left")

    # --- 年月日列を追加 ---
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day

    # --- max_temp_time / min_temp_time 分解 ---
    df["max_temp_time"] = pd.to_datetime(df["max_temp_time"])
    df["maxtemp_year"] = df["max_temp_time"].dt.year
    df["maxtemp_month"] = df["max_temp_time"].dt.month
    df["maxtemp_day"] = df["max_temp_time"].dt.day
    df["maxtemp_hour"] = df["max_temp_time"].dt.hour

    df["min_temp_time"] = pd.to_datetime(df["min_temp_time"])
    df["mintemp_year"] = df["min_temp_time"].dt.year
    df["mintemp_month"] = df["min_temp_time"].dt.month
    df["mintemp_day"] = df["min_temp_time"].dt.day
    df["mintemp_hour"]= df["min_temp_time"].dt.hour

    # --- 不要列削除 ---
    df = df.drop(columns=["date", "max_temp_time", "min_temp_time"])

    # --- category 型に変換 ---
    df["kind"] = df["kind"].astype("category")
    df["area"] = df["area"].astype("category")

    return df
weather["date"] = pd.to_datetime(weather["date"])

train_df = Data_cre(train_df)
test_df = Data_cre(test_df)

# %%
models = {}  # kind → model list or averaged は辞書に保存

K = 5  # ← Fold数

for kd, group in train_df.groupby("kind", observed=False):

    print(f"\n===== {kd} モデルをKFold({K})で学習中 =====")

    X = group.drop(columns=["mode_price"],axis=1)
    y = group["mode_price"]

    kf = KFold(n_splits=K, shuffle=True, random_state=42)

    fold_models = []  # foldごとのモデルを保存

    for fold, (train_index, valid_index) in enumerate(kf.split(X)):
        print(f"Fold {fold+1}/{K}")

        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        train_data = lgb.Dataset(X_train, y_train)
        valid_data = lgb.Dataset(X_valid, y_valid)

        params = {
            'objective': 'regression',
            'num_leaves': 5,
            'seed': fold,
            'verbose': -1,
        }

        model = lgb.train(
            params,
            train_data,
            num_boost_round=100,
            valid_sets=[train_data, valid_data],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(stopping_rounds=5, verbose=True),
                lgb.log_evaluation(50)
            ],
        )
        
        fold_models.append(model)

    models[kd] = fold_models  # kindごとにfoldモデルを保存
# Out:
# ===== いんげん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 220274	valid's l2: 270430
# [100]	train's l2: 192958	valid's l2: 244842
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 192958	valid's l2: 244842
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 222386	valid's l2: 236345
# [100]	train's l2: 200546	valid's l2: 213198
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 200725	valid's l2: 213100
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 230487	valid's l2: 223050
# [100]	train's l2: 200222	valid's l2: 201753
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 200222	valid's l2: 201753
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 225734	valid's l2: 219526
# [100]	train's l2: 199963	valid's l2: 192387
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 199963	valid's l2: 192387
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 228000	valid's l2: 206037
# [100]	train's l2: 202539	valid's l2: 183889
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 202539	valid's l2: 183889
#
# ===== うど モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 168130	valid's l2: 89999.5
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43980.7	valid's l2: 73263.5
# [100]	train's l2: 43978.2	valid's l2: 73088.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 43978.2	valid's l2: 73088.4
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 145663	valid's l2: 174983
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [21]	train's l2: 55152	valid's l2: 33378.4
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 52404.2	valid's l2: 38952.3
# [100]	train's l2: 52338.9	valid's l2: 37163.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 52338.9	valid's l2: 37163.8
#
# ===== うめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 576457	valid's l2: 737297
# Early stopping, best iteration is:
# [48]	train's l2: 581213	valid's l2: 732951
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 608359	valid's l2: 672625
# [100]	train's l2: 510528	valid's l2: 583502
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 510528	valid's l2: 583502
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 608394	valid's l2: 565509
# Early stopping, best iteration is:
# [90]	train's l2: 521660	valid's l2: 506622
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 607338	valid's l2: 566870
# [100]	train's l2: 506768	valid's l2: 517895
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 507289	valid's l2: 517340
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 574581	valid's l2: 828746
# Early stopping, best iteration is:
# [71]	train's l2: 527311	valid's l2: 788264
#
# ===== えだまめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3684.59	valid's l2: 3925.6
# Early stopping, best iteration is:
# [60]	train's l2: 3596.92	valid's l2: 3881.85
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3393.33	valid's l2: 4668.7
# Early stopping, best iteration is:
# [54]	train's l2: 3344.04	valid's l2: 4640.63
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3661.24	valid's l2: 3836.09
# Early stopping, best iteration is:
# [47]	train's l2: 3702.75	valid's l2: 3816.89
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3619.74	valid's l2: 3986.42
# Early stopping, best iteration is:
# [63]	train's l2: 3490.53	valid's l2: 3922.65
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3718.45	valid's l2: 3606.8
# Early stopping, best iteration is:
# [73]	train's l2: 3497.86	valid's l2: 3472.05
#
# ===== えのきだけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [5]	train's l2: 9.58252	valid's l2: 2.06516
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 6.73365	valid's l2: 10.663
# [100]	train's l2: 6.69801	valid's l2: 10.3348
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.69801	valid's l2: 10.3348
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [13]	train's l2: 7.71254	valid's l2: 7.45826
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 7.77889	valid's l2: 7.19262
# [100]	train's l2: 7.74302	valid's l2: 6.93759
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 7.74302	valid's l2: 6.93759
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [10]	train's l2: 7.01804	valid's l2: 11.644
#
# ===== かぶ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 413.279	valid's l2: 377.656
# [100]	train's l2: 362.906	valid's l2: 341.029
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 362.906	valid's l2: 341.029
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 418.26	valid's l2: 431.423
# [100]	train's l2: 364.348	valid's l2: 379.436
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 364.348	valid's l2: 379.436
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 415.482	valid's l2: 397.441
# [100]	train's l2: 363.692	valid's l2: 351.939
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 363.692	valid's l2: 351.939
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 409.04	valid's l2: 431.875
# [100]	train's l2: 357.265	valid's l2: 390.639
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 357.265	valid's l2: 390.639
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 404.156	valid's l2: 484.148
# [100]	train's l2: 353.273	valid's l2: 428.52
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 353.273	valid's l2: 428.52
#
# ===== かぼちゃ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 503025	valid's l2: 520180
# [100]	train's l2: 438070	valid's l2: 463247
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 438070	valid's l2: 463247
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 499566	valid's l2: 524241
# [100]	train's l2: 442264	valid's l2: 465878
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 442264	valid's l2: 465878
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 505539	valid's l2: 498579
# [100]	train's l2: 448591	valid's l2: 441400
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 448591	valid's l2: 441400
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 503916	valid's l2: 530879
# [100]	train's l2: 443180	valid's l2: 469283
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 443180	valid's l2: 469283
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 512420	valid's l2: 486497
# [100]	train's l2: 448699	valid's l2: 433265
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 448699	valid's l2: 433265
#
# ===== きゅうり モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 174044	valid's l2: 181860
# [100]	train's l2: 156177	valid's l2: 166063
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 156177	valid's l2: 166063
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 175685	valid's l2: 180009
# [100]	train's l2: 158420	valid's l2: 163471
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 158520	valid's l2: 163457
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 174255	valid's l2: 176102
# [100]	train's l2: 156364	valid's l2: 158177
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 156364	valid's l2: 158177
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 174951	valid's l2: 173428
# [100]	train's l2: 158319	valid's l2: 157221
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 158319	valid's l2: 157221
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 176267	valid's l2: 176447
# [100]	train's l2: 156604	valid's l2: 157673
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 156604	valid's l2: 157673
#
# ===== こまつな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3319.45	valid's l2: 3457.51
# [100]	train's l2: 2941.53	valid's l2: 3126.24
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2941.53	valid's l2: 3126.24
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3274.72	valid's l2: 3521.99
# [100]	train's l2: 2937.45	valid's l2: 3134.17
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2937.45	valid's l2: 3134.17
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3329.6	valid's l2: 3240.22
# [100]	train's l2: 2969.91	valid's l2: 2907.84
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2969.91	valid's l2: 2907.84
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3317.75	valid's l2: 3395.97
# [100]	train's l2: 3006.55	valid's l2: 3116.22
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 3006.55	valid's l2: 3116.22
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3350.56	valid's l2: 3260.16
# [100]	train's l2: 2941.53	valid's l2: 2870.31
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2941.53	valid's l2: 2870.31
#
# ===== ごぼう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 56227.7	valid's l2: 58474.1
# [100]	train's l2: 48645.9	valid's l2: 52734
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48645.9	valid's l2: 52734
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57436.2	valid's l2: 59778.4
# [100]	train's l2: 49659.4	valid's l2: 50985.5
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 49659.4	valid's l2: 50985.5
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57489.9	valid's l2: 58283.4
# [100]	train's l2: 48609.5	valid's l2: 50742.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48609.5	valid's l2: 50742.4
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 59065.2	valid's l2: 57462.8
# [100]	train's l2: 50112.2	valid's l2: 49375.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 50112.2	valid's l2: 49375.1
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57369	valid's l2: 59094
# [100]	train's l2: 48465.8	valid's l2: 51661.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48465.8	valid's l2: 51661.9
#
# ===== さつまいも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 67431.4	valid's l2: 68692.3
# [100]	train's l2: 60294.9	valid's l2: 62369.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 60294.9	valid's l2: 62369.6
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 67256.4	valid's l2: 69515.9
# [100]	train's l2: 59532.8	valid's l2: 62760.2
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 59610	valid's l2: 62735.1
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 68082.2	valid's l2: 64158.7
# [100]	train's l2: 60231.2	valid's l2: 58201.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 60231.2	valid's l2: 58201.3
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 67787.6	valid's l2: 66020.3
# [100]	train's l2: 60483.3	valid's l2: 58793.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 60483.3	valid's l2: 58793.9
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 65699.2	valid's l2: 72028.2
# [100]	train's l2: 58799.6	valid's l2: 64897.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 58799.6	valid's l2: 64897.3
#
# ===== さといも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 547072	valid's l2: 539177
# Early stopping, best iteration is:
# [70]	train's l2: 529936	valid's l2: 521873
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 527542	valid's l2: 610749
# [100]	train's l2: 492596	valid's l2: 580468
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 492596	valid's l2: 580468
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 547526	valid's l2: 559168
# Early stopping, best iteration is:
# [94]	train's l2: 507305	valid's l2: 532304
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 540742	valid's l2: 572354
# [100]	train's l2: 501321	valid's l2: 546696
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 501321	valid's l2: 546696
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 542954	valid's l2: 541899
# Early stopping, best iteration is:
# [46]	train's l2: 546443	valid's l2: 541045
#
# ===== さやえんどう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 176537	valid's l2: 243262
# Early stopping, best iteration is:
# [84]	train's l2: 158778	valid's l2: 228085
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 189872	valid's l2: 166641
# [100]	train's l2: 170131	valid's l2: 150676
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 170131	valid's l2: 150676
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 190062	valid's l2: 192556
# [100]	train's l2: 167686	valid's l2: 173903
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 167686	valid's l2: 173903
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 187228	valid's l2: 202868
# Early stopping, best iteration is:
# [56]	train's l2: 183158	valid's l2: 201030
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 177370	valid's l2: 231422
# [100]	train's l2: 158643	valid's l2: 213783
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 158643	valid's l2: 213783
#
# ===== しめじ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 3.13388	valid's l2: 0.551837
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 3.13388	valid's l2: 0.551837
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 2.42776	valid's l2: 3.20399
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 1.7049	valid's l2: 6.23161
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 2.41879	valid's l2: 3.32253
#
# ===== しゅんぎく モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 424.714	valid's l2: 508.057
# [100]	train's l2: 314.928	valid's l2: 390.239
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 314.928	valid's l2: 390.239
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 433.672	valid's l2: 471.526
# [100]	train's l2: 322.315	valid's l2: 359.047
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 322.315	valid's l2: 359.047
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 433.911	valid's l2: 473.518
# [100]	train's l2: 315.709	valid's l2: 369.336
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 315.709	valid's l2: 369.336
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 431.353	valid's l2: 427.94
# [100]	train's l2: 316.968	valid's l2: 316.568
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 316.968	valid's l2: 316.568
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 436.02	valid's l2: 422.872
# [100]	train's l2: 311.457	valid's l2: 308.947
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 311.457	valid's l2: 308.947
#
# ===== じゃがいも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 170175	valid's l2: 173775
# [100]	train's l2: 136363	valid's l2: 136308
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 136363	valid's l2: 136308
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 173559	valid's l2: 156542
# [100]	train's l2: 139008	valid's l2: 129337
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 139008	valid's l2: 129337
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 168268	valid's l2: 179015
# [100]	train's l2: 138004	valid's l2: 146505
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 138004	valid's l2: 146505
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 167581	valid's l2: 178487
# [100]	train's l2: 134210	valid's l2: 144234
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134210	valid's l2: 144234
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 168827	valid's l2: 172659
# [100]	train's l2: 136817	valid's l2: 144111
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 136817	valid's l2: 144111
#
# ===== そらまめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 261943	valid's l2: 270552
# [100]	train's l2: 239176	valid's l2: 255162
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 239176	valid's l2: 255162
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 256512	valid's l2: 274959
# [100]	train's l2: 230105	valid's l2: 251676
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 230105	valid's l2: 251676
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 259715	valid's l2: 255956
# [100]	train's l2: 229590	valid's l2: 238082
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 229590	valid's l2: 238082
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 259811	valid's l2: 262814
# [100]	train's l2: 231254	valid's l2: 238942
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 231254	valid's l2: 238942
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 250154	valid's l2: 301102
# [100]	train's l2: 223430	valid's l2: 281636
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 223430	valid's l2: 281636
#
# ===== たけのこ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 427807	valid's l2: 506396
# [100]	train's l2: 327380	valid's l2: 412344
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 327380	valid's l2: 412344
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 434703	valid's l2: 539631
# [100]	train's l2: 337698	valid's l2: 455843
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 337698	valid's l2: 455843
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 445869	valid's l2: 466079
# [100]	train's l2: 332014	valid's l2: 348452
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 333803	valid's l2: 348364
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 433551	valid's l2: 501536
# [100]	train's l2: 318158	valid's l2: 419258
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 318792	valid's l2: 418440
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 438912	valid's l2: 492250
# [100]	train's l2: 336107	valid's l2: 398788
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 336107	valid's l2: 398788
#
# ===== たまねぎ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 250178	valid's l2: 238947
# [100]	train's l2: 187931	valid's l2: 180569
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 187931	valid's l2: 180569
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 242487	valid's l2: 283497
# [100]	train's l2: 180372	valid's l2: 212895
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 180372	valid's l2: 212895
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 240204	valid's l2: 257953
# [100]	train's l2: 185318	valid's l2: 202017
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 185318	valid's l2: 202017
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 255557	valid's l2: 246558
# [100]	train's l2: 190317	valid's l2: 181596
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 190317	valid's l2: 181596
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 253638	valid's l2: 244184
# [100]	train's l2: 182782	valid's l2: 186783
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 182782	valid's l2: 186783
#
# ===== だいこん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55272.8	valid's l2: 53878.9
# [100]	train's l2: 47030.6	valid's l2: 46620.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 47030.6	valid's l2: 46620.2
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55723.8	valid's l2: 56298.3
# [100]	train's l2: 46733.8	valid's l2: 47584.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 46733.8	valid's l2: 47584.4
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55261.4	valid's l2: 58888.1
# [100]	train's l2: 47553.1	valid's l2: 50651.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 47553.1	valid's l2: 50651.2
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55579.2	valid's l2: 59583.2
# [100]	train's l2: 48134.6	valid's l2: 51893.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48134.6	valid's l2: 51893.9
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 56346.5	valid's l2: 53229.5
# [100]	train's l2: 48592.2	valid's l2: 46364.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48592.2	valid's l2: 46364.9
#
# ===== とうもろこし モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 44519	valid's l2: 43217.6
# [100]	train's l2: 39441.1	valid's l2: 39637.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 39441.1	valid's l2: 39637.2
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43527.8	valid's l2: 46015.2
# [100]	train's l2: 38279.1	valid's l2: 42395.5
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 38313.7	valid's l2: 42374.6
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43593.4	valid's l2: 47626.8
# [100]	train's l2: 38475.2	valid's l2: 43595.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 38475.2	valid's l2: 43595.8
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43390.9	valid's l2: 49609.9
# [100]	train's l2: 38953.7	valid's l2: 44764.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 38953.7	valid's l2: 44764.4
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 44732.9	valid's l2: 43331.7
# [100]	train's l2: 39094	valid's l2: 38438.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 39094	valid's l2: 38438.6
#
# ===== なす モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 131327	valid's l2: 127315
# [100]	train's l2: 117116	valid's l2: 112868
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 117116	valid's l2: 112868
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 131661	valid's l2: 119024
# [100]	train's l2: 118757	valid's l2: 108382
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 118757	valid's l2: 108382
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 127541	valid's l2: 142368
# [100]	train's l2: 113678	valid's l2: 129701
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 113678	valid's l2: 129701
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 130970	valid's l2: 131403
# [100]	train's l2: 116813	valid's l2: 118853
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 116813	valid's l2: 118853
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 128011	valid's l2: 141513
# [100]	train's l2: 116478	valid's l2: 131149
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 116478	valid's l2: 131149
#
# ===== なのはな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1088.85	valid's l2: 1081.06
# [100]	train's l2: 944.714	valid's l2: 994.576
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 946.798	valid's l2: 993.565
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 994.167	valid's l2: 1443.93
# [100]	train's l2: 865.564	valid's l2: 1309.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 865.564	valid's l2: 1309.2
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1058.19	valid's l2: 979.218
# Early stopping, best iteration is:
# [94]	train's l2: 931.113	valid's l2: 918.397
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1039.18	valid's l2: 1312.21
# [100]	train's l2: 910.659	valid's l2: 1165.88
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 910.659	valid's l2: 1165.88
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1057.28	valid's l2: 1265.28
# Early stopping, best iteration is:
# [73]	train's l2: 981.08	valid's l2: 1225.59
#
# ===== なましいたけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 182.318	valid's l2: 174.901
# [100]	train's l2: 135.676	valid's l2: 137.687
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 135.676	valid's l2: 137.687
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 178.9	valid's l2: 167.575
# [100]	train's l2: 134.479	valid's l2: 127.966
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134.479	valid's l2: 127.966
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 175.633	valid's l2: 190.834
# [100]	train's l2: 132.616	valid's l2: 146.961
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 132.616	valid's l2: 146.961
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 179.502	valid's l2: 198.492
# [100]	train's l2: 134.322	valid's l2: 146.333
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134.322	valid's l2: 146.333
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 180.457	valid's l2: 179.244
# [100]	train's l2: 134.026	valid's l2: 135.145
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134.026	valid's l2: 135.145
#
# ===== にら モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [39]	train's l2: 86.8878	valid's l2: 109.052
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 85.3667	valid's l2: 92.3878
# Early stopping, best iteration is:
# [72]	train's l2: 78.7648	valid's l2: 90.0861
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 81.0063	valid's l2: 125.556
# [100]	train's l2: 66.9493	valid's l2: 110.321
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 66.9493	valid's l2: 110.321
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [44]	train's l2: 91.7313	valid's l2: 86.8057
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 85.9786	valid's l2: 94.3852
# [100]	train's l2: 72.9935	valid's l2: 83.7252
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 72.9935	valid's l2: 83.7252
#
# ===== にんじん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 153654	valid's l2: 164547
# [100]	train's l2: 127329	valid's l2: 138334
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 127329	valid's l2: 138334
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156637	valid's l2: 167084
# [100]	train's l2: 129303	valid's l2: 136617
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 129303	valid's l2: 136617
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 157675	valid's l2: 153238
# [100]	train's l2: 134125	valid's l2: 131284
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134125	valid's l2: 131284
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152186	valid's l2: 159272
# [100]	train's l2: 130086	valid's l2: 135244
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130086	valid's l2: 135244
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 158989	valid's l2: 146984
# [100]	train's l2: 132168	valid's l2: 126417
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 132310	valid's l2: 126406
#
# ===== ねぎ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 158850	valid's l2: 148992
# [100]	train's l2: 131780	valid's l2: 121071
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 131780	valid's l2: 121071
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 148108	valid's l2: 162886
# [100]	train's l2: 124200	valid's l2: 140171
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 124200	valid's l2: 140171
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156459	valid's l2: 137769
# [100]	train's l2: 131909	valid's l2: 117929
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 131909	valid's l2: 117929
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 160854	valid's l2: 163707
# [100]	train's l2: 131704	valid's l2: 131781
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 131704	valid's l2: 131781
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 151363	valid's l2: 170623
# [100]	train's l2: 126732	valid's l2: 145647
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126732	valid's l2: 145647
#
# ===== はくさい モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 153051	valid's l2: 138970
# [100]	train's l2: 131468	valid's l2: 121020
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 131468	valid's l2: 121020
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152236	valid's l2: 153358
# [100]	train's l2: 127634	valid's l2: 130116
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 127634	valid's l2: 130116
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 151332	valid's l2: 146511
# [100]	train's l2: 129187	valid's l2: 125717
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 129187	valid's l2: 125717
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 146376	valid's l2: 182406
# [100]	train's l2: 122782	valid's l2: 151996
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 122782	valid's l2: 151996
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152066	valid's l2: 147481
# [100]	train's l2: 127745	valid's l2: 127564
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 127745	valid's l2: 127564
#
# ===== ふき モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19858.1	valid's l2: 18640.7
# [100]	train's l2: 17261.2	valid's l2: 16745.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 17261.2	valid's l2: 16745.9
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19343.8	valid's l2: 21921.8
# [100]	train's l2: 16946.8	valid's l2: 20549.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 16946.8	valid's l2: 20549.6
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 18937.1	valid's l2: 24128.7
# [100]	train's l2: 16578.1	valid's l2: 22635.4
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 16621.4	valid's l2: 22605.6
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19589.4	valid's l2: 20273.6
# [100]	train's l2: 17040.1	valid's l2: 18323
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 17040.1	valid's l2: 18323
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19989.5	valid's l2: 22155.8
# Early stopping, best iteration is:
# [90]	train's l2: 17351.3	valid's l2: 20340.9
#
# ===== ほうれんそう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 677.497	valid's l2: 690.691
# [100]	train's l2: 604.585	valid's l2: 613.826
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 604.585	valid's l2: 613.826
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 692.288	valid's l2: 668.205
# [100]	train's l2: 602.56	valid's l2: 584.754
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 602.56	valid's l2: 584.754
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 686.045	valid's l2: 716.365
# [100]	train's l2: 597.42	valid's l2: 644.984
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 597.42	valid's l2: 644.984
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 681.77	valid's l2: 692.779
# [100]	train's l2: 605.74	valid's l2: 629.734
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 605.74	valid's l2: 629.734
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 687.459	valid's l2: 709.244
# [100]	train's l2: 606.294	valid's l2: 639.198
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 606.294	valid's l2: 639.198
#
# ===== まつたけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.44721e+06	valid's l2: 1.06578e+07
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.40527e+06	valid's l2: 1.04411e+07
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.91889e+06	valid's l2: 8.7802e+06
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.53015e+06	valid's l2: 8.83335e+06
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.01653e+06	valid's l2: 1.06545e+07
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
#
# ===== みずな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 205.698	valid's l2: 214.262
# [100]	train's l2: 157.586	valid's l2: 195.482
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 158.026	valid's l2: 195.265
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 197.041	valid's l2: 328.527
# [100]	train's l2: 157.685	valid's l2: 280.011
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 157.685	valid's l2: 280.011
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 217.267	valid's l2: 183.437
# [100]	train's l2: 171.696	valid's l2: 152.26
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 171.696	valid's l2: 152.26
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 216.429	valid's l2: 230.422
# [100]	train's l2: 166.994	valid's l2: 187.392
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 166.994	valid's l2: 187.392
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 223.436	valid's l2: 220.321
# [100]	train's l2: 174.524	valid's l2: 175.754
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 174.524	valid's l2: 175.754
#
# ===== れんこん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26138.7	valid's l2: 31419.2
# [100]	train's l2: 21276.1	valid's l2: 26037.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21276.1	valid's l2: 26037.8
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26061.5	valid's l2: 30566
# Early stopping, best iteration is:
# [93]	train's l2: 21605.4	valid's l2: 26962.5
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26976.2	valid's l2: 29299.7
# [100]	train's l2: 22071.7	valid's l2: 24482
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 22071.7	valid's l2: 24482
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 27233.2	valid's l2: 31274.5
# [100]	train's l2: 22000.1	valid's l2: 25288.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 22000.1	valid's l2: 25288.8
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26343.7	valid's l2: 28588.4
# [100]	train's l2: 21174.7	valid's l2: 24470.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21174.7	valid's l2: 24470.4
#
# ===== アスパラガス モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 143.595	valid's l2: 124.582
# [100]	train's l2: 121.321	valid's l2: 113.711
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 121.321	valid's l2: 113.711
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 133.056	valid's l2: 220.737
# [100]	train's l2: 108.578	valid's l2: 198.954
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 108.578	valid's l2: 198.954
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 134.36	valid's l2: 161.925
# [100]	train's l2: 107.762	valid's l2: 137.807
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 107.762	valid's l2: 137.807
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 144.82	valid's l2: 187.419
# [100]	train's l2: 118.398	valid's l2: 140.904
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 118.398	valid's l2: 140.904
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 141.606	valid's l2: 132.322
# [100]	train's l2: 119.345	valid's l2: 115.74
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 119.345	valid's l2: 115.74
#
# ===== オクラ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 157.878	valid's l2: 218.335
# [100]	train's l2: 126.281	valid's l2: 181.141
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126.281	valid's l2: 181.141
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 174.59	valid's l2: 196.328
# [100]	train's l2: 141.638	valid's l2: 168.757
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 141.638	valid's l2: 168.757
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 169.473	valid's l2: 206.898
# Early stopping, best iteration is:
# [82]	train's l2: 147.471	valid's l2: 188.251
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 164.651	valid's l2: 191.611
# Early stopping, best iteration is:
# [73]	train's l2: 142.881	valid's l2: 175.501
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [41]	train's l2: 180.21	valid's l2: 147.943
#
# ===== キャベツ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 96417.6	valid's l2: 95440.9
# [100]	train's l2: 82913.6	valid's l2: 81070.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 82913.6	valid's l2: 81070.8
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 95188.5	valid's l2: 87062
# [100]	train's l2: 80931.9	valid's l2: 75973.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80931.9	valid's l2: 75973.6
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93551	valid's l2: 99106.2
# [100]	train's l2: 80664.6	valid's l2: 86615.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80664.6	valid's l2: 86615.8
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 96375.4	valid's l2: 94222.9
# [100]	train's l2: 81713.4	valid's l2: 80416.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 81713.4	valid's l2: 80416.9
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93339	valid's l2: 103033
# [100]	train's l2: 79410.6	valid's l2: 86812.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79410.6	valid's l2: 86812.9
#
# ===== セルリー モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156251	valid's l2: 154739
# [100]	train's l2: 132484	valid's l2: 135834
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 132484	valid's l2: 135834
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152160	valid's l2: 171852
# [100]	train's l2: 129611	valid's l2: 148179
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 129611	valid's l2: 148179
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 154033	valid's l2: 172553
# [100]	train's l2: 130255	valid's l2: 149881
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130255	valid's l2: 149881
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156436	valid's l2: 156339
# [100]	train's l2: 132674	valid's l2: 135102
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 132674	valid's l2: 135102
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 159216	valid's l2: 146857
# [100]	train's l2: 135536	valid's l2: 126561
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 135536	valid's l2: 126561
#
# ===== トマト モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 95385.6	valid's l2: 89042.3
# [100]	train's l2: 80664	valid's l2: 75191.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80664	valid's l2: 75191.7
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 94492.9	valid's l2: 97463.4
# [100]	train's l2: 79860.3	valid's l2: 83425.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79860.3	valid's l2: 83425.6
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92475.9	valid's l2: 96179.8
# [100]	train's l2: 80032	valid's l2: 84569.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80032	valid's l2: 84569.4
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92537.1	valid's l2: 96990.6
# [100]	train's l2: 77849	valid's l2: 82425.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 77849	valid's l2: 82425.4
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93306.9	valid's l2: 93113.7
# [100]	train's l2: 79338.3	valid's l2: 78965.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79338.3	valid's l2: 78965.9
#
# ===== ピース モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 121515	valid's l2: 182035
# Early stopping, best iteration is:
# [75]	train's l2: 110509	valid's l2: 170132
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [42]	train's l2: 135201	valid's l2: 129423
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 122067	valid's l2: 203728
# Early stopping, best iteration is:
# [79]	train's l2: 108029	valid's l2: 190387
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 128475	valid's l2: 111135
# [100]	train's l2: 105758	valid's l2: 96852.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 105758	valid's l2: 96852.9
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [28]	train's l2: 146730	valid's l2: 199771
#
# ===== ピーマン モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 260.479	valid's l2: 256.386
# [100]	train's l2: 226.45	valid's l2: 222.622
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 226.45	valid's l2: 222.622
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 259.244	valid's l2: 269.414
# [100]	train's l2: 226.047	valid's l2: 239.15
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 226.047	valid's l2: 239.15
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 258.674	valid's l2: 269.806
# [100]	train's l2: 226.113	valid's l2: 237.577
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 226.113	valid's l2: 237.577
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 264.269	valid's l2: 253.076
# [100]	train's l2: 228.53	valid's l2: 222.379
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 228.53	valid's l2: 222.379
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 259.492	valid's l2: 270.648
# [100]	train's l2: 227.318	valid's l2: 237.684
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 227.318	valid's l2: 237.684
#
# ===== ブロッコリー モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 111643	valid's l2: 139522
# [100]	train's l2: 94223.4	valid's l2: 117505
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 94223.4	valid's l2: 117505
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 109655	valid's l2: 132116
# [100]	train's l2: 87695.8	valid's l2: 115840
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 87695.8	valid's l2: 115840
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 115185	valid's l2: 109043
# [100]	train's l2: 96618.3	valid's l2: 89994.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 96618.3	valid's l2: 89994.3
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 113579	valid's l2: 112539
# [100]	train's l2: 93483.3	valid's l2: 99471.5
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 93483.3	valid's l2: 99471.5
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 116708	valid's l2: 107037
# [100]	train's l2: 94252	valid's l2: 90886.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 94252	valid's l2: 90886.7
#
# ===== ミニトマト モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 513.786	valid's l2: 722.116
# [100]	train's l2: 442.498	valid's l2: 651.207
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 442.498	valid's l2: 651.207
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 583.088	valid's l2: 425.673
# [100]	train's l2: 497.656	valid's l2: 358.185
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 497.656	valid's l2: 358.185
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 577.212	valid's l2: 535.004
# [100]	train's l2: 499.381	valid's l2: 461.072
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 499.381	valid's l2: 461.072
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 573.719	valid's l2: 498.847
# [100]	train's l2: 492.831	valid's l2: 424.855
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 492.831	valid's l2: 424.855
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 517.317	valid's l2: 688.907
# [100]	train's l2: 431.795	valid's l2: 636.078
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 431.795	valid's l2: 636.078
#
# ===== レイシにがうり モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 22844.6	valid's l2: 23582.3
# [100]	train's l2: 18764.5	valid's l2: 20711.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 18764.5	valid's l2: 20711.7
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 22878	valid's l2: 26388.5
# [100]	train's l2: 18999.9	valid's l2: 22945.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 18999.9	valid's l2: 22945.7
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 22050.2	valid's l2: 27669.4
# [100]	train's l2: 17806	valid's l2: 23111.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 17806	valid's l2: 23111.9
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 23627.6	valid's l2: 22510.5
# [100]	train's l2: 18678.9	valid's l2: 18858.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 18678.9	valid's l2: 18858.3
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 23095.1	valid's l2: 25119.4
# [100]	train's l2: 19341.7	valid's l2: 21901.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 19341.7	valid's l2: 21901.9
#
# ===== レタス モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 446105	valid's l2: 418419
# [100]	train's l2: 386625	valid's l2: 368834
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 386625	valid's l2: 368834
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 433188	valid's l2: 474756
# [100]	train's l2: 367525	valid's l2: 414146
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 367525	valid's l2: 414146
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 430406	valid's l2: 459448
# [100]	train's l2: 371138	valid's l2: 396900
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 371138	valid's l2: 396900
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 442782	valid's l2: 456315
# [100]	train's l2: 389858	valid's l2: 400607
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 389858	valid's l2: 400607
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 425435	valid's l2: 417748
# [100]	train's l2: 364004	valid's l2: 368264
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 364004	valid's l2: 368264

# %%
import numpy as np

pred_list = []

for kd, group in test_df.groupby("kind"):

    fold_models = models[kd]  # ← foldモデルが複数入っている
    X_test = group.copy()

    # 全 fold モデルの予測を行い平均
    fold_pred = np.mean([m.predict(X_test) for m in fold_models], axis=0)

    X_test["mode_price"] = fold_pred
    pred_list.append(X_test)

# まとめ・並び順合わせ
result = pd.concat(pred_list).sort_index()

# 日付整形（year,month,day → YYYYMMDD）
result["date"] = (
    result["year"].astype(str)
    + result["month"].astype(str).str.zfill(2)
    + result["day"].astype(str).str.zfill(2)
)
result["date"] = result["date"].astype(int)

# 提出形式に整形
submit = result[["kind", "date", "mode_price"]]

submit
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_14140\846674396.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for kd, group in test_df.groupby("kind"):
#       kind      date   mode_price
# 0     だいこん  20220502  1007.290322
# 1     だいこん  20220502  1052.215336
# 2     だいこん  20220502  1057.904760
# 3     だいこん  20220506  1007.290322
# 4     だいこん  20220506  1052.215336
# ..     ...       ...          ...
# 815  ミニトマト  20220528   102.769817
# 816  ミニトマト  20220530   102.990850
# 817  ミニトマト  20220530   102.990850
# 818  ミニトマト  20220531   104.152180
# 819  ミニトマト  20220531   104.152180
#
# [820 rows x 3 columns]

# %%
submit_mean = (
    submit.groupby(["kind", "date"], as_index=False)["mode_price"]
          .mean()
)
# ① area 側の kind の出現順を取得
kind_order = test_df["kind"].drop_duplicates().tolist()

# ② price 側の kind を Categorical に変換して順序を固定
submit_mean["kind"] = pd.Categorical(submit_mean["kind"], categories=kind_order, ordered=True)

# ③ 並び替え
df_price_sorted = submit_mean.sort_values(["kind", "date"]).reset_index(drop=True)
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_14140\975664683.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   submit.groupby(["kind", "date"], as_index=False)["mode_price"]

# %%
df_price_sorted.to_csv("submit_lgb.csv", index=False)
df_price_sorted
# Out:
#       kind      date   mode_price
# 0     だいこん  20220502  1039.136806
# 1     だいこん  20220506  1039.136806
# 2     だいこん  20220507  1034.473760
# 3     だいこん  20220509  1033.763412
# 4     だいこん  20220510  1033.763412
# ..     ...       ...          ...
# 315  ミニトマト  20220526   103.190671
# 316  ミニトマト  20220527   103.190671
# 317  ミニトマト  20220528   102.769817
# 318  ミニトマト  20220530   102.990850
# 319  ミニトマト  20220531   104.152180
#
# [320 rows x 3 columns]
