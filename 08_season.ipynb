# %% [markdown]
# - 特徴量seasonを入れる
# -

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
test_df = pd.read_csv("test.csv")
train_df = pd.read_csv("train.csv")
weather = pd.read_csv("weather.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
test_df
# Out:
#       kind      date      area
# 0     だいこん  20220502  千葉_各地_青森
# 1     だいこん  20220506  千葉_各地_青森
# 2     だいこん  20220507  千葉_各地_青森
# 3     だいこん  20220509  千葉_各地_青森
# 4     だいこん  20220510  千葉_各地_青森
# ..     ...       ...       ...
# 315  ミニトマト  20220526     各地_愛知
# 316  ミニトマト  20220527     各地_愛知
# 317  ミニトマト  20220528     各地_愛知
# 318  ミニトマト  20220530     各地_愛知
# 319  ミニトマト  20220531     各地_愛知
#
# [320 rows x 3 columns]

# %%
weather
# Out:
#             date  mean_temp  max_temp     max_temp_time  min_temp  \
# 0       20041106       13.1      20.1   2004/11/6 12:50       8.1
# 1       20041107        9.6      12.5   2004/11/7 13:40       5.4
# 2       20041108        9.0      15.5   2004/11/8 12:51       3.2
# 3       20041109       12.2      17.7   2004/11/9 14:40       5.7
# 4       20041110       11.6      16.4  2004/11/10 14:42       6.9
# ...          ...        ...       ...               ...       ...
# 204315  20220426       21.3      23.6   2022/4/26 14:27      17.9
# 204316  20220427       23.0      27.7   2022/4/27 13:12      18.9
# 204317  20220428       16.9      21.1   2022/4/28 15:03      14.2
# 204318  20220429       12.9      16.4   2022/4/29 09:21       9.0
# 204319  20220430       12.6      18.4   2022/4/30 14:49       7.4
#
#            min_temp_time  sum_rain  sun_time  mean_humid area
# 0        2004/11/6 05:31       5.0       1.6        77.0   青森
# 1        2004/11/7 22:17       0.0       4.1        63.0   青森
# 2        2004/11/8 06:28       0.0       8.9        72.0   青森
# 3        2004/11/9 02:49       1.5       1.2        85.0   青森
# 4       2004/11/10 06:23       0.0       7.5        89.0   青森
# ...                  ...       ...       ...         ...  ...
# 204315   2022/4/26 04:17       2.5       0.0        89.0   東京
# 204316    2022/4/28 0:00       0.5       1.6        79.0   東京
# 204317   2022/4/28 22:40       0.0       5.5        57.0   東京
# 204318   2022/4/29 23:55      40.0       0.2        86.0   東京
# 204319   2022/4/30 05:28       0.0      12.4        64.0   東京
#
# [204320 rows x 10 columns]

# %%
sample
# Out:
#       kind      date  mode_price
# 0     だいこん  20220502           0
# 1     だいこん  20220506           0
# 2     だいこん  20220507           0
# 3     だいこん  20220509           0
# 4     だいこん  20220510           0
# ..     ...       ...         ...
# 315  ミニトマト  20220526           0
# 316  ミニトマト  20220527           0
# 317  ミニトマト  20220528           0
# 318  ミニトマト  20220530           0
# 319  ミニトマト  20220531           0
#
# [320 rows x 3 columns]

# %%
#profile = ProfileReport(train_df, title="Profiling Report")
#profile.to_notebook_iframe()
#profile.to_file("your_report.html")
# amount削除
train_df = train_df.drop(columns=['amount'])

# %%
# 季節を判定する関数（日本の四季）
def get_season(month: int) -> str:
    if month in [3, 4, 5]:
        return "春"
    elif month in [6, 7, 8]:
        return "夏"
    elif month in [9, 10, 11]:
        return "秋"
    else:  # 12, 1, 2
        return "冬"

# %%
def Data_cre(df):
    # --- area を分解して複数行に展開 ---
    df["area_list"] = df["area"].str.split("_")

    # explodeで行を増やす
    df = df.explode("area_list")
    df = df.drop(columns=["area"])
    df = df.rename(columns={"area_list": "area"})

    # --- 日付フォーマット揃え ---
    df["date"] = df["date"].astype(str)
    df["date"] = pd.to_datetime(df["date"])

    # --- weather と結合 ---
    df = pd.merge(df, weather, on=["date", "area"], how="left")

    # --- 年月日列を追加 ---
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day

    # --- max_temp_time / min_temp_time 分解 ---
    df["max_temp_time"] = pd.to_datetime(df["max_temp_time"])
    df["maxtemp_year"] = df["max_temp_time"].dt.year
    df["maxtemp_month"] = df["max_temp_time"].dt.month
    df["maxtemp_day"] = df["max_temp_time"].dt.day
    df["maxtemp_hour"] = df["max_temp_time"].dt.hour

    df["min_temp_time"] = pd.to_datetime(df["min_temp_time"])
    df["mintemp_year"] = df["min_temp_time"].dt.year
    df["mintemp_month"] = df["min_temp_time"].dt.month
    df["mintemp_day"] = df["min_temp_time"].dt.day
    df["mintemp_hour"]= df["min_temp_time"].dt.hour



    # 月を抽出して季節列を追加
    df["season"] = df["date"].dt.month.apply(get_season)
    # --- 不要列削除 ---
    df = df.drop(columns=["date", "max_temp_time", "min_temp_time"])

    # --- category 型に変換 ---
    df["kind"] = df["kind"].astype("category")
    df["area"] = df["area"].astype("category")
    df["season"] = df["season"].astype("category")

    return df
weather["date"] = pd.to_datetime(weather["date"])

train_df = Data_cre(train_df)

test_df = Data_cre(test_df)

# %%
train_df["area"]
# Out:
# 0         千葉
# 1         千葉
# 2         各地
# 3         青森
# 4         千葉
#           ..
# 212120    長野
# 212121    新潟
# 212122    長野
# 212123    新潟
# 212124    長野
# Name: area, Length: 212125, dtype: category
# Categories (39, object): ['アメリカ', 'カナダ', 'トンガ', 'ニュージーランド', ..., '静岡', '香川', '高知', '鹿児島']

# %%
train_df
# Out:
#         kind  mode_price area  mean_temp  max_temp  min_temp  sum_rain  \
# 0       だいこん       735.0   千葉        NaN       NaN       NaN       NaN
# 1       だいこん       840.0   千葉        NaN       NaN       NaN       NaN
# 2       だいこん       840.0   各地        NaN       NaN       NaN       NaN
# 3       だいこん       840.0   青森        NaN       NaN       NaN       NaN
# 4       だいこん       735.0   千葉        NaN       NaN       NaN       NaN
# ...      ...         ...  ...        ...       ...       ...       ...
# 212120   しめじ        48.5   長野        NaN       NaN       NaN       NaN
# 212121   しめじ        48.5   新潟        NaN       NaN       NaN       NaN
# 212122   しめじ        48.5   長野        NaN       NaN       NaN       NaN
# 212123   しめじ        43.0   新潟        NaN       NaN       NaN       NaN
# 212124   しめじ        43.0   長野        NaN       NaN       NaN       NaN
#
#         sun_time  mean_humid  year  ...  day  maxtemp_year  maxtemp_month  \
# 0            NaN         NaN  2005  ...    7           NaN            NaN
# 1            NaN         NaN  2005  ...    8           NaN            NaN
# 2            NaN         NaN  2005  ...    8           NaN            NaN
# 3            NaN         NaN  2005  ...    8           NaN            NaN
# 4            NaN         NaN  2005  ...   10           NaN            NaN
# ...          ...         ...   ...  ...  ...           ...            ...
# 212120       NaN         NaN  2017  ...   29           NaN            NaN
# 212121       NaN         NaN  2017  ...   30           NaN            NaN
# 212122       NaN         NaN  2017  ...   30           NaN            NaN
# 212123       NaN         NaN  2017  ...   31           NaN            NaN
# 212124       NaN         NaN  2017  ...   31           NaN            NaN
#
#         maxtemp_day  maxtemp_hour  mintemp_year  mintemp_month  mintemp_day  \
# 0               NaN           NaN           NaN            NaN          NaN
# 1               NaN           NaN           NaN            NaN          NaN
# 2               NaN           NaN           NaN            NaN          NaN
# 3               NaN           NaN           NaN            NaN          NaN
# 4               NaN           NaN           NaN            NaN          NaN
# ...             ...           ...           ...            ...          ...
# 212120          NaN           NaN           NaN            NaN          NaN
# 212121          NaN           NaN           NaN            NaN          NaN
# 212122          NaN           NaN           NaN            NaN          NaN
# 212123          NaN           NaN           NaN            NaN          NaN
# 212124          NaN           NaN           NaN            NaN          NaN
#
#         mintemp_hour  season
# 0                NaN       秋
# 1                NaN       秋
# 2                NaN       秋
# 3                NaN       秋
# 4                NaN       秋
# ...              ...     ...
# 212120           NaN       春
# 212121           NaN       春
# 212122           NaN       春
# 212123           NaN       春
# 212124           NaN       春
#
# [212125 rows x 21 columns]

# %%
X = train_df.drop(['mode_price'], axis=1)
y = train_df['mode_price']
# 学習データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# %%
### chatgpt
from sklearn.model_selection import KFold
import numpy as np
import lightgbm as lgb

models = {}  # kind → model list or averaged は辞書に保存

K = 5  # ← Fold数

for kd, group in train_df.groupby("kind", observed=False):

    print(f"\n===== {kd} モデルをKFold({K})で学習中 =====")

    X = group.drop(columns=["mode_price"],axis=1)
    y = group["mode_price"]

    kf = KFold(n_splits=K, shuffle=True, random_state=42)

    fold_models = []  # foldごとのモデルを保存

    for fold, (train_index, valid_index) in enumerate(kf.split(X)):
        print(f"Fold {fold+1}/{K}")

        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        train_data = lgb.Dataset(X_train, y_train)
        valid_data = lgb.Dataset(X_valid, y_valid)

        params = {
            'objective': 'regression',
            'num_leaves': 5,
            'seed': fold,
            'verbose': -1,
        }

        model = lgb.train(
            params,
            train_data,
            num_boost_round=100,
            valid_sets=[train_data, valid_data],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(stopping_rounds=5, verbose=True),
                lgb.log_evaluation(50)
            ],
        )
        
        fold_models.append(model)

    models[kd] = fold_models  # kindごとにfoldモデルを保存
# Out:
# ===== いんげん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 218456	valid's l2: 269783
# [100]	train's l2: 191878	valid's l2: 245789
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 191878	valid's l2: 245789
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 221887	valid's l2: 234437
# [100]	train's l2: 200239	valid's l2: 212672
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 200239	valid's l2: 212672
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 228114	valid's l2: 221272
# [100]	train's l2: 198859	valid's l2: 201155
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 198859	valid's l2: 201155
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2:
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 18937.1	valid's l2: 24128.7
# [100]	train's l2: 16578.1	valid's l2: 22635.4
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 16621.4	valid's l2: 22605.6
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19589.4	valid's l2: 20273.6
# [100]	train's l2: 17040.1	valid's l2: 18323
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 17040.1	valid's l2: 18323
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19989.5	valid's l2: 22155.8
# Early stopping, best iteration is:
# [90]	train's l2: 17351.3	valid's l2: 20340.9
#
# ===== ほうれんそう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 662.442	valid's l2: 675.847
# [100]	train's l2: 590.14	valid's l2: 607.133
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 590.14	valid's l2: 607.133
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 683.247	valid's l2: 653.11
# [100]	train's l2: 603.933	valid's l2: 581.872
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 603.933	valid's l2: 581.872
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 675.425	valid's l2: 710.559
# [100]	train's l2: 590.574	valid's l2: 631.788
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 590.574	valid's l2: 631.788
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 674.593	valid's l2: 687.459
# [100]	train's l2: 598.998	valid's l2: 617.213
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 598.998	valid's l2: 617.213
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 681.931	valid's l2: 697.31
# [100]	train's l2: 610.703	valid's l2: 634.93
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 610.703	valid's l2: 634.93
#
# ===== まつたけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.44721e+06	valid's l2: 1.06578e+07
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.40527e+06	valid's l2: 1.04411e+07
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.91889e+06	valid's l2: 8.7802e+06
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.53015e+06	valid's l2: 8.83335e+06
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.01653e+06	valid's l2: 1.06545e+07
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
#
# ===== みずな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 205.698	valid's l2: 214.262
# [100]	train's l2: 157.586	valid's l2: 195.482
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 158.026	valid's l2: 195.265
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 197.041	valid's l2: 328.527
# [100]	train's l2: 157.685	valid's l2: 280.011
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 157.685	valid's l2: 280.011
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 217.267	valid's l2: 183.437
# [100]	train's l2: 171.696	valid's l2: 152.26
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 171.696	valid's l2: 152.26
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 216.429	valid's l2: 230.422
# [100]	train's l2: 166.994	valid's l2: 187.392
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 166.994	valid's l2: 187.392
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 223.436	valid's l2: 220.321
# [100]	train's l2: 174.524	valid's l2: 175.754
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 174.524	valid's l2: 175.754
#
# ===== れんこん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26138.7	valid's l2: 31419.2
# [100]	train's l2: 21276.1	valid's l2: 26037.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21276.1	valid's l2: 26037.8
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26061.5	valid's l2: 30566
# Early stopping, best iteration is:
# [93]	train's l2: 21605.4	valid's l2: 26962.5
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26976.2	valid's l2: 29299.7
# [100]	train's l2: 22071.7	valid's l2: 24482
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 22071.7	valid's l2: 24482
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 27233.2	valid's l2: 31274.5
# [100]	train's l2: 22000.1	valid's l2: 25288.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 22000.1	valid's l2: 25288.8
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26343.7	valid's l2: 28588.4
# [100]	train's l2: 21174.7	valid's l2: 24470.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21174.7	valid's l2: 24470.4
#
# ===== アスパラガス モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 143.595	valid's l2: 124.582
# [100]	train's l2: 121.321	valid's l2: 113.711
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 121.321	valid's l2: 113.711
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 133.056	valid's l2: 220.737
# [100]	train's l2: 108.578	valid's l2: 198.954
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 108.578	valid's l2: 198.954
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 134.36	valid's l2: 161.925
# [100]	train's l2: 107.762	valid's l2: 137.807
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 107.762	valid's l2: 137.807
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 144.82	valid's l2: 187.419
# [100]	train's l2: 118.398	valid's l2: 140.904
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 118.398	valid's l2: 140.904
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 141.606	valid's l2: 132.322
# [100]	train's l2: 119.345	valid's l2: 115.74
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 119.345	valid's l2: 115.74
#
# ===== オクラ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 157.878	valid's l2: 218.335
# [100]	train's l2: 126.281	valid's l2: 181.141
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126.281	valid's l2: 181.141
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 174.59	valid's l2: 196.328
# [100]	train's l2: 141.638	valid's l2: 168.757
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 141.638	valid's l2: 168.757
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 169.473	valid's l2: 206.898
# Early stopping, best iteration is:
# [82]	train's l2: 147.471	valid's l2: 188.251
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 164.651	valid's l2: 191.611
# Early stopping, best iteration is:
# [73]	train's l2: 142.881	valid's l2: 175.501
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [41]	train's l2: 180.21	valid's l2: 147.943
#
# ===== キャベツ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 90880.8	valid's l2: 88386
# [100]	train's l2: 77249.2	valid's l2: 73697.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 77249.2	valid's l2: 73697.9
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93042.8	valid's l2: 85742
# [100]	train's l2: 78333.1	valid's l2: 73990.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78333.1	valid's l2: 73990.1
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 88672.5	valid's l2: 94278.2
# [100]	train's l2: 77410.6	valid's l2: 83863.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 77410.6	valid's l2: 83863.2
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 91793	valid's l2: 90350.8
# [100]	train's l2: 78210.6	valid's l2: 77519.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78210.6	valid's l2: 77519.8
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 90449.5	valid's l2: 98591.1
# [100]	train's l2: 75378.1	valid's l2: 80694.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 75378.1	valid's l2: 80694.1
#
# ===== セルリー モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 155752	valid's l2: 154758
# [100]	train's l2: 130794	valid's l2: 134608
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130794	valid's l2: 134608
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 153253	valid's l2: 172493
# [100]	train's l2: 129787	valid's l2: 146042
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 129787	valid's l2: 146042
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152454	valid's l2: 172854
# [100]	train's l2: 128084	valid's l2: 147237
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 128084	valid's l2: 147237
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 155369	valid's l2: 155490
# [100]	train's l2: 129588	valid's l2: 134750
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 129588	valid's l2: 134750
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 158402	valid's l2: 146106
# [100]	train's l2: 135215	valid's l2: 125458
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 135323	valid's l2: 125430
#
# ===== トマト モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 95011.1	valid's l2: 88763.7
# [100]	train's l2: 82255.3	valid's l2: 76823.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 82255.3	valid's l2: 76823.4
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93058.6	valid's l2: 96041.9
# [100]	train's l2: 80410.1	valid's l2: 84332.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80410.1	valid's l2: 84332.7
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 91724.4	valid's l2: 96028.3
# [100]	train's l2: 79729.3	valid's l2: 84299.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79729.3	valid's l2: 84299.7
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93019.7	valid's l2: 96677.7
# [100]	train's l2: 78834.9	valid's l2: 83116.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78834.9	valid's l2: 83116.8
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92970.9	valid's l2: 92804.9
# [100]	train's l2: 82331.1	valid's l2: 82031.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 82331.1	valid's l2: 82031.7
#
# ===== ピース モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 121515	valid's l2: 182035
# Early stopping, best iteration is:
# [75]	train's l2: 110509	valid's l2: 170132
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
#
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 361227	valid's l2: 407094
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 455800	valid's l2: 491732
# [100]	train's l2: 374430	valid's l2: 394771
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 374430	valid's l2: 394771
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 444211	valid's l2: 463021
# [100]	train's l2: 385920	valid's l2: 402057
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 385920	valid's l2: 402057
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 444013	valid's l2: 433575
# [100]	train's l2: 387916	valid's l2: 388249
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 387916	valid's l2: 388249

# %%
models
# Out:
# {'いんげん': [<lightgbm.basic.Booster at 0x2084775c980>,
#   <lightgbm.basic.Booster at 0x2083db266c0>,
#   <lightgbm.basic.Booster at 0x2084775ddf0>,
#   <lightgbm.basic.Booster at 0x2084775ce60>,
#   <lightgbm.basic.Booster at 0x208486c1250>],
#  'うど': [<lightgbm.basic.Booster at 0x2084775e4e0>,
#   <lightgbm.basic.Booster at 0x208486c2ed0>,
#   <lightgbm.basic.Booster at 0x2084775d010>,
#   <lightgbm.basic.Booster at 0x208486c1550>,
#   <lightgbm.basic.Booster at 0x2084775ebd0>],
#  'うめ': [<lightgbm.basic.Booster at 0x208486c0890>,
#   <lightgbm.basic.Booster at 0x208486c2210>,
#   <lightgbm.basic.Booster at 0x20845513d40>,
#   <lightgbm.basic.Booster at 0x2083aee16d0>,
#   <lightgbm.basic.Booster at 0x2084775de50>],
#  'えだまめ': [<lightgbm.basic.Booster at 0x2084775df10>,
#   <lightgbm.basic.Booster at 0x208454cf350>,
#   <lightgbm.basic.Booster at 0x208454cf650>,
#   <lightgbm.basic.Booster at 0x208486c1f10>,
#   <lightgbm.basic.Booster at 0x208486c35c0>],
#  'えのきだけ': [<lightgbm.basic.Booster at 0x208486c2f60>,
#   <lightgbm.basic.Booster at 0x208486c0e30>,
#   <lightgbm.basic.Booster at 0x20845513230>,
#   <lightgbm.basic.Booster at 0x208486c1fa0>,
#   <lightgbm.basic.Booster at 0x208486c0590>],
#  'かぶ': [<lightgbm.basic.Booster at 0x208486c2360>,
#   <lightgbm.basic.Booster at 0x208486c1190>,
#   <lightgbm.basic.Booster at 0x2083aee15b0>,
#   <lightgbm.basic.Booster at 0x208455109b0>,
#   <lightgbm.basic.Booster at 0x20845513620>],
#  'かぼちゃ': [<lightgbm.basic.Booster at 0x20848930ef0>,
#   <lightgbm.basic.Booster at 0x208486c1fd0>,
#   <lightgbm.basic.Booster at 0x208486c31d0>,
#   <lightgbm.basic.Booster at 0x208489323c0>,
#   <lightgbm.basic.Booster at 0x208489333b0>],
#  'きゅうり': [<lightgbm.basic.Booster at 0x208489339b0>,
#   <lightgbm.basic.Booster at 0x2084775c9b0>,
#   <lightgbm.basic.Booster at 0x208489336e0>,
#   <lightgbm.basic.Booster at 0x20848932630>,
#   <lightgbm.basic.Booster at 0x20848933e30>],
#  'こまつな': [<lightgbm.basic.Booster at 0x208489334a0>,
#   <lightgbm.basic.Booster at 0x20848932750>,
#   <lightgbm.basic.Booster at 0x20848933c20>,
#   <lightgbm.basic.Booster at 0x208489318b0>,
#   <lightgbm.basic.Booster at 0x20848933f20>],
#  'ごぼう': [<lightgbm.basic.Booster at 0x208489321e0>,
#   <lightgbm.basic.Booster at 0x20848931880>,
#   <lightgbm.basic.Booster at 0x20848931a30>,
#   <lightgbm.basic.Booster at 0x20848932900>,
#   <lightgbm.basic.Booster at 0x20848933e90>],
#  'さつまいも': [<lightgbm.basic.Booster at 0x208477c4860>,
#   <lightgbm.basic.Booster at 0x20848932780>,
#   <lightgbm.basic.Booster at 0x20848930f20>,
#   <lightgbm.basic.Booster at 0x20848932480>,
#   <lightgbm.basic.Booster at 0x208477c44a0>],
#  'さといも': [<lightgbm.basic.Booster at 0x208477c62d0>,
#   <lightgbm.basic.Booster at 0x208477c6e10>,
#   <lightgbm.basic.Booster at 0x20843496f60>,
#   <lightgbm.basic.Booster at 0x208477c6240>,
#   <lightgbm.basic.Booster at 0x208477c7770>],
#  'さやえんどう': [<lightgbm.basic.Booster at 0x20843b6e900>,
#   <lightgbm.basic.Booster at 0x208477c73e0>,
#   <lightgbm.basic.Booster at 0x208477c5370>,
#   <lightgbm.basic.Booster at 0x20848932c30>,
#   <lightgbm.basic.Booster at 0x2084775e8d0>],
#  'しめじ': [<lightgbm.basic.Booster at 0x208477c7a10>,
#   <lightgbm.basic.Booster at 0x208477c7ec0>,
#   <lightgbm.basic.Booster at 0x208477c55e0>,
#   <lightgbm.basic.Booster at 0x208477c6480>,
#   <lightgbm.basic.Booster at 0x208477c7170>],
#  'しゅんぎく': [<lightgbm.basic.Booster at 0x208477c7740>,
#   <lightgbm.basic.Booster at 0x208477c7470>,
#   <lightgbm.basic.Booster at 0x208477c5790>,
#   <lightgbm.basic.Booster at 0x208477c6ed0>,
#   <lightgbm.basic.Booster at 0x208477c6930>],
#  'じゃがいも': [<lightgbm.basic.Booster at 0x208486c2450>,
#   <lightgbm.basic.Booster at 0x208486c0710>,
#   <lightgbm.basic.Booster at 0x208477e8770>,
#   <lightgbm.basic.Booster at 0x208477c7380>,
#   <lightgbm.basic.Booster at 0x20848933fe0>],
#  'そらまめ': [<lightgbm.basic.Booster at 0x208477e8fe0>,
#   <lightgbm.basic.Booster at 0x208477ea6f0>,
#   <lightgbm.basic.Booster at 0x208477c65a0>,
#   <lightgbm.basic.Booster at 0x20848931400>,
#   <lightgbm.basic.Booster at 0x20848931be0>],
#  'たけのこ': [<lightgbm.basic.Booster at 0x20848932420>,
#   <lightgbm.basic.Booster at 0x20848932ff0>,
#   <lightgbm.basic.Booster at 0x20843634e90>,
#   <lightgbm.basic.Booster at 0x208486c1790>,
#   <lightgbm.basic.Booster at 0x208486c14c0>],
#  'たまねぎ': [<lightgbm.basic.Booster at 0x208486c1520>,
#   <lightgbm.basic.Booster at 0x208486c1b20>,
#   <lightgbm.basic.Booster at 0x20848930200>,
#   <lightgbm.basic.Booster at 0x20848931850>,
#   <lightgbm.basic.Booster at 0x208486c0530>],
#  'だいこん': [<lightgbm.basic.Booster at 0x208486c10d0>,
#   <lightgbm.basic.Booster at 0x208486c1850>,
#   <lightgbm.basic.Booster at 0x20848932ae0>,
#   <lightgbm.basic.Booster at 0x20848932a50>,
#   <lightgbm.basic.Booster at 0x208486c1730>],
#  'とうもろこし': [<lightgbm.basic.Booster at 0x20848930dd0>,
#   <lightgbm.basic.Booster at 0x20848931220>,
#   <lightgbm.basic.Booster at 0x208477c6360>,
#   <lightgbm.basic.Booster at 0x208477c7890>,
#   <lightgbm.basic.Booster at 0x208477c7dd0>],
#  'なす': [<lightgbm.basic.Booster at 0x208489328a0>,
#   <lightgbm.basic.Booster at 0x208477c4a10>,
#   <lightgbm.basic.Booster at 0x20845513aa0>,
#   <lightgbm.basic.Booster at 0x208477c50d0>,
#   <lightgbm.basic.Booster at 0x208477c7e00>],
#  'なのはな': [<lightgbm.basic.Booster at 0x20848930da0>,
#   <lightgbm.basic.Booster at 0x208477c7f80>,
#   <lightgbm.basic.Booster at 0x20845512840>,
#   <lightgbm.basic.Booster at 0x208477c4f80>,
#   <lightgbm.basic.Booster at 0x20848930a10>],
#  'なましいたけ': [<lightgbm.basic.Booster at 0x208477c6450>,
#   <lightgbm.basic.Booster at 0x208455128d0>,
#   <lightgbm.basic.Booster at 0x2084775fe90>,
#   <lightgbm.basic.Booster at 0x208477c4770>,
#   <lightgbm.basic.Booster at 0x20848933830>],
#  'にら': [<lightgbm.basic.Booster at 0x208489326c0>,
#   <lightgbm.basic.Booster at 0x208486c1a30>,
#   <lightgbm.basic.Booster at 0x208477c56d0>,
#   <lightgbm.basic.Booster at 0x208477c5f10>,
#   <lightgbm.basic.Booster at 0x20845512f00>],
#  'にんじん': [<lightgbm.basic.Booster at 0x208477c6510>,
#   <lightgbm.basic.Booster at 0x208477e82c0>,
#   <lightgbm.basic.Booster at 0x208477ea5a0>,
#   <lightgbm.basic.Booster at 0x20845512960>,
#   <lightgbm.basic.Booster at 0x208477c6060>],
#  'ねぎ': [<lightgbm.basic.Booster at 0x208477e9a30>,
#   <lightgbm.basic.Booster at 0x20848933860>,
#   <lightgbm.basic.Booster at 0x208477c75c0>,
#   <lightgbm.basic.Booster at 0x208477eb350>,
#   <lightgbm.basic.Booster at 0x208477e89e0>],
#  'はくさい': [<lightgbm.basic.Booster at 0x208477e9e80>,
#   <lightgbm.basic.Booster at 0x208477e95e0>,
#   <lightgbm.basic.Booster at 0x2084775d820>,
#   <lightgbm.basic.Booster at 0x208477ea450>,
#   <lightgbm.basic.Booster at 0x208477ea7e0>],
#  'ふき': [<lightgbm.basic.Booster at 0x20848931280>,
#   <lightgbm.basic.Booster at 0x208477e9a60>,
#   <lightgbm.basic.Booster at 0x208486c2cc0>,
#   <lightgbm.basic.Booster at 0x208477ebc50>,
#   <lightgbm.basic.Booster at 0x208477eb890>],
#  'ほうれんそう': [<lightgbm.basic.Booster at 0x208477ea960>,
#   <lightgbm.basic.Booster at 0x208489ee2a0>,
#   <lightgbm.basic.Booster at 0x208489ed400>,
#   <lightgbm.basic.Booster at 0x2084775e3f0>,
#   <lightgbm.basic.Booster at 0x208477e8e00>],
#  'まつたけ': [<lightgbm.basic.Booster at 0x208489ee120>,
#   <lightgbm.basic.Booster at 0x208477e90d0>,
#   <lightgbm.basic.Booster at 0x208489320f0>,
#   <lightgbm.basic.Booster at 0x208489eeb40>,
#   <lightgbm.basic.Booster at 0x208489ef200>],
#  'みずな': [<lightgbm.basic.Booster at 0x208489ed670>,
#   <lightgbm.basic.Booster at 0x208486c1d90>,
#   <lightgbm.basic.Booster at 0x208477e9cd0>,
#   <lightgbm.basic.Booster at 0x208489ec8f0>,
#   <lightgbm.basic.Booster at 0x208489ef9b0>],
#  'れんこん': [<lightgbm.basic.Booster at 0x208489ef5c0>,
#   <lightgbm.basic.Booster at 0x208489ef4d0>,
#   <lightgbm.basic.Booster at 0x208489ee720>,
#   <lightgbm.basic.Booster at 0x208489eed20>,
#   <lightgbm.basic.Booster at 0x208489ef9e0>],
#  'アスパラガス': [<lightgbm.basic.Booster at 0x208489ef290>,
#   <lightgbm.basic.Booster at 0x208477ebce0>,
#   <lightgbm.basic.Booster at 0x208489ee630>,
#   <lightgbm.basic.Booster at 0x208489ec710>,
#   <lightgbm.basic.Booster at 0x208477c7530>],
#  'オクラ': [<lightgbm.basic.Booster at 0x208489ef980>,
#   <lightgbm.basic.Booster at 0x208489ecf50>,
#   <lightgbm.basic.Booster at 0x20845513dd0>,
#   <lightgbm.basic.Booster at 0x208489efd10>,
#   <lightgbm.basic.Booster at 0x2084b4a89e0>],
#  'キャベツ': [<lightgbm.basic.Booster at 0x208486c3290>,
#   <lightgbm.basic.Booster at 0x208489edc40>,
#   <lightgbm.basic.Booster at 0x208477c4b90>,
#   <lightgbm.basic.Booster at 0x208486c18b0>,
#   <lightgbm.basic.Booster at 0x208486c23c0>],
#  'セルリー': [<lightgbm.basic.Booster at 0x2084b4aae40>,
#   <lightgbm.basic.Booster at 0x20848932720>,
#   <lightgbm.basic.Booster at 0x20848932810>,
#   <lightgbm.basic.Booster at 0x208486c27e0>,
#   <lightgbm.basic.Booster at 0x2084b4a97f0>],
#  'トマト': [<lightgbm.basic.Booster at 0x208486c1670>,
#   <lightgbm.basic.Booster at 0x208489ee450>,
#   <lightgbm.basic.Booster at 0x2084b4ab230>,
#   <lightgbm.basic.Booster at 0x2084b4abad0>,
#   <lightgbm.basic.Booster at 0x208486c2780>],
#  'ピース': [<lightgbm.basic.Booster at 0x2084b4ab950>,
#   <lightgbm.basic.Booster at 0x2084b4a8800>,
#   <lightgbm.basic.Booster at 0x2084b4aa120>,
#   <lightgbm.basic.Booster at 0x2084b4aa6c0>,
#   <lightgbm.basic.Booster at 0x2084b4aa750>],
#  'ピーマン': [<lightgbm.basic.Booster at 0x2084b4ab5c0>,
#   <lightgbm.basic.Booster at 0x2084b4aaea0>,
#   <lightgbm.basic.Booster at 0x2084b4a8530>,
#   <lightgbm.basic.Booster at 0x2084b4abe90>,
#   <lightgbm.basic.Booster at 0x2084b4aaf00>],
#  'ブロッコリー': [<lightgbm.basic.Booster at 0x208489324e0>,
#   <lightgbm.basic.Booster at 0x2084b4a9e20>,
#   <lightgbm.basic.Booster at 0x2084b4aaa20>,
#   <lightgbm.basic.Booster at 0x2084b4aaa80>,
#   <lightgbm.basic.Booster at 0x2084b4a8da0>],
#  'ミニトマト': [<lightgbm.basic.Booster at 0x2084b4a9760>,
#   <lightgbm.basic.Booster at 0x2084b4aba70>,
#   <lightgbm.basic.Booster at 0x2084b4ab860>,
#   <lightgbm.basic.Booster at 0x2084b515cd0>,
#   <lightgbm.basic.Booster at 0x2084b4abda0>],
#  'レイシにがうり': [<lightgbm.basic.Booster at 0x208477eb6b0>,
#   <lightgbm.basic.Booster at 0x2084b4a9550>,
#   <lightgbm.basic.Booster at 0x2084b5151f0>,
#   <lightgbm.basic.Booster at 0x2084b5157c0>,
#   <lightgbm.basic.Booster at 0x20848931760>],
#  'レタス': [<lightgbm.basic.Booster at 0x2084b4aa5a0>,
#   <lightgbm.basic.Booster at 0x2084b516ed0>,
#   <lightgbm.basic.Booster at 0x2084b514b60>,
#   <lightgbm.basic.Booster at 0x208489314c0>,
#   <lightgbm.basic.Booster at 0x2084b517620>]}

# %%
import numpy as np

pred_list = []

for kd, group in test_df.groupby("kind"):

    fold_models = models[kd]  # ← foldモデルが複数入っている
    X_test = group.copy()

    # 全 fold モデルの予測を行い平均
    fold_pred = np.mean([m.predict(X_test) for m in fold_models], axis=0)

    X_test["mode_price"] = fold_pred
    pred_list.append(X_test)

# まとめ・並び順合わせ
result = pd.concat(pred_list).sort_index()

# 日付整形（year,month,day → YYYYMMDD）
result["date"] = (
    result["year"].astype(str)
    + result["month"].astype(str).str.zfill(2)
    + result["day"].astype(str).str.zfill(2)
)
result["date"] = result["date"].astype(int)

# 提出形式に整形
submit = result[["kind", "date", "mode_price"]]

submit
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_2908\846674396.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for kd, group in test_df.groupby("kind"):
#       kind      date   mode_price
# 0     だいこん  20220502  1039.137690
# 1     だいこん  20220502  1079.183725
# 2     だいこん  20220502  1083.917028
# 3     だいこん  20220506  1039.137690
# 4     だいこん  20220506  1079.183725
# ..     ...       ...          ...
# 815  ミニトマト  20220528    99.765216
# 816  ミニトマト  20220530   100.177157
# 817  ミニトマト  20220530    99.992929
# 818  ミニトマト  20220531   101.148342
# 819  ミニトマト  20220531   100.964115
#
# [820 rows x 3 columns]

# %%
submit_mean = (
    submit.groupby(["kind", "date"], as_index=False)["mode_price"]
          .mean()
)
# ① area 側の kind の出現順を取得
kind_order = test_df["kind"].drop_duplicates().tolist()

# ② price 側の kind を Categorical に変換して順序を固定
submit_mean["kind"] = pd.Categorical(submit_mean["kind"], categories=kind_order, ordered=True)

# ③ 並び替え
df_price_sorted = submit_mean.sort_values(["kind", "date"]).reset_index(drop=True)
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_2908\975664683.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   submit.groupby(["kind", "date"], as_index=False)["mode_price"]

# %%
df_price_sorted.to_csv("submit.csv", index=False)
df_price_sorted
# Out:
#       kind      date   mode_price
# 0     だいこん  20220502  1067.412814
# 1     だいこん  20220506  1067.412814
# 2     だいこん  20220507  1056.818150
# 3     だいこん  20220509  1056.818150
# 4     だいこん  20220510  1056.818150
# ..     ...       ...          ...
# 315  ミニトマト  20220526   101.448398
# 316  ミニトマト  20220527   101.448398
# 317  ミニトマト  20220528    99.857329
# 318  ミニトマト  20220530   100.085043
# 319  ミニトマト  20220531   101.056229
#
# [320 rows x 3 columns]
